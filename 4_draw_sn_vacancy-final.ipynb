# %%
def pickup_draw(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, thermal_pick, zt_pick, pf_pick,q,ax0,Atom):
    mark=['o','v','^','<','>','.','1','2','3','4']
    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    el_pick.append(el_cond[numrow])
    seebeck_pick.append(seebeck[numrow])
    thermal_pick.append(thermal[numrow])
    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))
    pf_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*10**(-6))    
    if id[numrow] != id[numrow+1]:
        vacancy=(1-(sn[numrow]+dopant_ratio[numrow])/0.99)
        if vacancy == 0:
            q=0      

           
        ax0.plot(temp_pick,zt_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax0.legend()

        el_pick=list()
        seebeck_pick=list()
        thermal_pick=list()
        zt_pick=list()
        pf_pick=list()
        q+=1
        
    return zt_pick,q


def pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,Atom):
    mark=['o','v','^','<','>','.','1','2','3','4']
    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    el_pick.append(el_cond[numrow])
    seebeck_pick.append(seebeck[numrow])
    thermal_pick.append(thermal[numrow])
    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))
    pf_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*10**(-6))    
    
    if id[numrow] != id[numrow+1]:
        vacancy=(1-(sn[numrow]+dopant_ratio[numrow])/0.99)
        
        if vacancy == 0:
            q=0      
            fig,ax0,ax1,ax2,ax3,ax4=figsetting(fig,ax0,ax1,ax2,ax3,ax4)
            
            
        ax0.plot(temp_pick,zt_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax0.legend()
        ax1.plot(temp_pick,el_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax2.plot(temp_pick,seebeck_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax3.plot(temp_pick,thermal_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax4.plot(temp_pick,pf_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        
        
        el_pick=list()
        seebeck_pick=list()
        thermal_pick=list()
        zt_pick=list()
        pf_pick=list()
        q+=1
        if dopant_ratio[numrow] == 0.0495 and q==1:
            
            fig.savefig('./outputdata_search/vacancy/'+str(Atom)+'_vacancy.pdf')
            plt.show()
                
        elif dopant_ratio[numrow] == 0.0396 and q==2:
            
            
            fig.savefig('./outputdata_search/vacancy/'+str(Atom)+'_vacancy.pdf')                
            plt.show()
                
        elif q == 3:
            #fig.savefig('vacancy_'+str(Atom)+'.pdf')
            
            fig.savefig('./outputdata_search/vacancy/'+str(Atom)+'_vacancy.pdf')            
            plt.show()
        

        
    return el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q, fig,ax0,ax1,ax2,ax3,ax4

def pickup_draw_3(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,Atom):
    mark=['o','v','^','<','>','.','1','2','3','4']
    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    el_pick.append(el_cond[numrow])
    seebeck_pick.append(seebeck[numrow])
    thermal_pick.append(thermal[numrow])
    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))
    pf_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*10**(-6))    
    
    if id[numrow] != id[numrow+1]:
        vacancy=(0.99-sn[numrow])
        
        if vacancy == 0:
            q=0      
            fig,ax0,ax1,ax2,ax3,ax4=figsetting(fig,ax0,ax1,ax2,ax3,ax4)
            
            
        ax0.plot(temp_pick,zt_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax0.legend()
        ax1.plot(temp_pick,el_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax2.plot(temp_pick,seebeck_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax3.plot(temp_pick,thermal_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        ax4.plot(temp_pick,pf_pick,marker=mark[q], label=str(Atom)+'_'+'{:.2f}'.format(dopant_ratio[numrow])+'_Sn vac_'+'{:.2f}'.format(vacancy))
        
        
        el_pick=list()
        seebeck_pick=list()
        thermal_pick=list()
        zt_pick=list()
        pf_pick=list()
        q+=1
        
               
        

        if dopant_ratio[numrow] == 0.05 and q==1:
            
            fig.savefig('./outputdata_search/vacancy/'+str(Atom)+'_vacancy.pdf')
            plt.show()
                
        elif dopant_ratio[numrow] == 0.04 and q==2:
            
            
            fig.savefig('./outputdata_search/vacancy/'+str(Atom)+'_vacancy.pdf')                
            plt.show()
                
        elif q == 3:
            #fig.savefig('vacancy_'+str(Atom)+'.pdf')
            
            fig.savefig('./outputdata_search/vacancy/'+str(Atom)+'_vacancy.pdf')            
            plt.show()        
        
        
        
    return el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q, fig,ax0,ax1,ax2,ax3,ax4

def figsetting(fig,ax0,ax1,ax2,ax3,ax4):
    fig.clf()
    fig = plt.figure(figsize=(20,3.5))
    ax0 = plt.subplot(1,5,1)
    ax1 = plt.subplot(1,5,2)
    ax2 = plt.subplot(1,5,3)
    ax3 = plt.subplot(1,5,4)
    ax4 = plt.subplot(1,5,5)
    #ax5 = plt.subplot(2,3,6)

    ax0.set_xlim((300,820))
    ax1.set_xlim((300,820))
    ax2.set_xlim((300,820))
    ax3.set_xlim((300,820))
    ax4.set_xlim((300,820))


    ax0.set_ylim((0,2.5))
    ax1.set_ylim((0,140))
    ax2.set_ylim((140,450))
    ax3.set_ylim((0.2,0.9))
    ax4.set_ylim((0,11))



    #ax.set_ylim((0,4))
    ax0.set_xlabel('Temperature')
    ax1.set_xlabel('Temperature')
    ax2.set_xlabel('Temperature')
    ax3.set_xlabel('Temperature')
    ax4.set_xlabel('Temperature')
    

    ax0.set_ylabel('predicted ZT')
    ax1.set_ylabel('predicted s')
    ax2.set_ylabel('predicted S')
    ax3.set_ylabel('predicted k')
    ax4.set_ylabel('predicted PF')
    
    return fig,ax0,ax1,ax2,ax3,ax4

# %%
filename='solubility_total.csv'
solubility_df=pd.read_csv(filename,index_col=0)
solubility_atomlist=solubility_df['atom'].values.tolist()
solubility=solubility_df.solubility.values


#ZT screening
import pickle
from joblib import dump, load
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

from elements import ELEMENTS
from myfunction import my_range


# %matplotlib inline

numrow=0
starttemp  = 300
endtemp    = 820
steptemp   = 20

zero=0
startratio = 1
endratio   = 5
stepratio  = 1

ids=0
element_list=['Li','Be', 'B','C','Na','Mg', 'Al','Si','P','K','Ca','Sc','Ti','V','Cr','Mn','Fe',\
        'Co','Ni','Cu','Zn','Ga','Ge','As','Rb','Sr','Y','Zr','Nb','Mo','Ru','Rh','Pd','Ag',\
        'Cd','In','Sb','Cs','Ba','Hf','Ta','W','Re','Os','Ir','Pt','Au','Hg','Tl','Pb','Bi']




zt_data=pd.read_csv('./outputdata_search/zt_search_Na.csv',index_col=0)
id=zt_data.ID
el_cond=zt_data.el_cond
seebeck=zt_data.seebeck
thermal=zt_data.thermal
zt_pred=zt_data.ZT
temp=zt_data.Temp
sn=zt_data.Sn_ratio
dopant=zt_data.dopant2_num
dopant_ratio=zt_data.dopant2_ratio
direction=zt_data.direction
draw_list=['zt_pick']

for tt in draw_list:
    
    numrow=0
    el_pick=list()
    seebeck_pick=list()
    thermal_pick=list()
    zt_pick=list()
    pf_pick=list()

    fig = plt.figure(figsize=(16,10))
    ax0 = plt.subplot(2,3,1)
    ax1 = plt.subplot(2,3,2)
    ax2 = plt.subplot(2,3,3)
    ax3 = plt.subplot(2,3,4)
    ax4 = plt.subplot(2,3,5)
    ax5 = plt.subplot(2,3,6)

    ax0.set_xlim((300,820))
    ax1.set_xlim((300,820))
    ax2.set_xlim((300,820))
    ax3.set_xlim((300,820))
    ax4.set_xlim((300,820))
    ax5.set_xlim((300,820))


    ax0.set_ylim((0,2.5))
    ax1.set_ylim((0,2.5))
    ax2.set_ylim((0,2.5))
    ax3.set_ylim((0,2.5))
    ax4.set_ylim((0,2.5))
    ax5.set_ylim((0,2.5))



    ax0.set_xlabel('Temperature')
    ax1.set_xlabel('Temperature')
    ax2.set_xlabel('Temperature')
    ax3.set_xlabel('Temperature')
    ax4.set_xlabel('Temperature')
    ax5.set_xlabel('Temperature')


    ax0.set_ylabel('predicted ZT')

    ax5.set_ylabel('predicted ZT')

    mark=['o','v','^','<','>','.','1','2','3','4']
    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    
    q=0


    for element in element_list:
        
        endratio=5    
        endratio_s=solubility[solubility_atomlist.index(element)]
        endratio_s=round(endratio_s)
            
        if endratio > endratio_s:
            endratio = endratio_s
        if endratio_s > 0.5 and endratio_s < 1.0:
            endratio = 1            

           
        for ii in my_range(startratio,endratio,stepratio):  #from 1% to 3%, stepsize=1%

            if ii ==5 :
                vacancy = 0
            elif ii==4 : 
                vacancy = 1
            else:
                vacancy = 2


            for jj in my_range(0,vacancy,stepratio):  #from 1% to 3%, stepsize=1%

                x_trial=[] 
                y_fitted=[]

                for direction in [0,1]:
                    
                    for i in my_range(starttemp,endtemp,steptemp): #input of temperature data

                        # Sn substitute & Na 1%
                        composition= [numrow,'TY'+str("{0:0=4d}".format(ids)),(1-(ii+jj)*0.01)*0.99,1,11,0.01,\
                                              ELEMENTS[element].number,ii*0.01*0.99,0,0,direction,i]

                        
                        if (dopant[numrow] ==32 ) and (dopant_ratio[numrow] == 0.0396) and (direction == 0) :
                            zt_pick,q=pickup_draw(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,ax1,'Ge')

                        elif (dopant[numrow] ==82 ) and (np.abs(dopant_ratio[numrow] - 0.0297)<0.001) and (direction == 0) :
                            
                            zt_pick,q=pickup_draw(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,ax2,'Pb')

                        elif (dopant[numrow] ==48 ) and (dopant_ratio[numrow] == 0.0099) and (direction == 0) :
                            zt_pick,q=pickup_draw(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,ax3,'Cd')

                        elif (dopant[numrow] ==39 ) and (dopant_ratio[numrow] == 0.0099) and (direction == 0) :
                            zt_pick,q=pickup_draw(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,ax4,'Y')

                        elif (dopant[numrow] ==33 ) and (dopant_ratio[numrow] == 0.0396) and (direction == 0) :
                            zt_pick,q=pickup_draw(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,ax5,'As')


                        numrow+=1

                    ids+=1

    plt.show()
    fig.savefig('./outputdata_search/vacancy_Na.pdf',format='pdf')
    print('write complete Na')
# Out:
# write complete Na

# %%
#ZT screening
import pickle
from joblib import dump, load
import csv
import numpy as np
from elements import ELEMENTS
from myfunction import my_range
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

numrow=0
starttemp  = 300
endtemp    = 820
steptemp   = 20

zero=0
startratio = 1
endratio   = 5
stepratio  = 1

ids=0
element_list=['Li','Be', 'B','C','Na','Mg', 'Al','Si','P','K','Ca','Sc','Ti','V','Cr','Mn','Fe',\
        'Co','Ni','Cu','Zn','Ga','Ge','As','Rb','Sr','Y','Zr','Nb','Mo','Ru','Rh','Pd','Ag',\
        'Cd','In','Sb','Cs','Ba','Hf','Ta','W','Re','Os','Ir','Pt','Au','Hg','Tl','Pb','Bi']




zt_data=pd.read_csv('./outputdata_search/zt_search_Na.csv',index_col=0)
id=zt_data.ID
el_cond=zt_data.el_cond
seebeck=zt_data.seebeck
thermal=zt_data.thermal
zt_pred=zt_data.ZT
temp=zt_data.Temp
sn=zt_data.Sn_ratio
dopant=zt_data.dopant2_num
dopant_ratio=zt_data.dopant2_ratio
direction=zt_data.direction
draw_list=['zt_pick']

for tt in draw_list:
    
    numrow=0
    el_pick=list()
    seebeck_pick=list()
    thermal_pick=list()
    zt_pick=list()
    pf_pick=list()

    fig = plt.figure(figsize=(20,3.5))
    ax0 = plt.subplot(1,5,1)
    ax1 = plt.subplot(1,5,2)
    ax2 = plt.subplot(1,5,3)
    ax3 = plt.subplot(1,5,4)
    ax4 = plt.subplot(1,5,5)
    #ax5 = plt.subplot(2,3,6)

    ax0.set_xlim((300,820))
    ax1.set_xlim((300,820))
    ax2.set_xlim((300,820))
    ax3.set_xlim((300,820))
    ax4.set_xlim((300,820))
    


    ax0.set_ylim((0,2.5))
    ax1.set_ylim((0,140))
    ax2.set_ylim((140,450))
    ax3.set_ylim((0.2,0.9))
    ax4.set_ylim((0,11))


    
    ax0.set_xlabel('Temperature')
    ax1.set_xlabel('Temperature')
    ax2.set_xlabel('Temperature')
    ax3.set_xlabel('Temperature')
    ax4.set_xlabel('Temperature')


    ax0.set_ylabel('predicted ZT')
    ax1.set_ylabel('predicted s')
    ax2.set_ylabel('predicted S')
    ax3.set_ylabel('predicted k')
    ax4.set_ylabel('predicted PF')

    mark=['o','v','^','<','>','.','1','2','3','4']
    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    
    q=0
    for element in element_list:
        
        endratio=5    
        endratio_s=solubility[solubility_atomlist.index(element)]
        endratio_s=round(endratio_s)
            
        if endratio > endratio_s:
            endratio = endratio_s
        if endratio_s > 0.5 and endratio_s < 1.0:
            endratio = 1            

           
        for ii in my_range(startratio,endratio,stepratio):  #from 1% to 3%, stepsize=1%

            if ii ==5 :
                vacancy = 0
            elif ii==4 : 
                vacancy = 1
            else:
                vacancy = 2


            for jj in my_range(0,vacancy,stepratio):  #from 1% to 3%, stepsize=1%

                x_trial=[] 
                y_fitted=[]

                for direction in [0,1]:
                    
                    for i in my_range(starttemp,endtemp,steptemp): #input of temperature data

                        # Sn substitute & Na 1%
                        composition= [numrow,'TY'+str("{0:0=4d}".format(ids)),(1-(ii+jj)*0.01)*0.99,1,11,0.01,\
                                              ELEMENTS[element].number,ii*0.01*0.99,0,0,direction,i]




                        if (dopant[numrow] ==32 ) and (dopant_ratio[numrow] == 0.0396) and (direction == 0) :
                            el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,element)

                        elif (dopant[numrow] ==82 ) and  (np.abs(dopant_ratio[numrow] - 0.0297)<0.001) and (direction == 0) :
                            el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,element)


                        elif (dopant[numrow] ==48 ) and (dopant_ratio[numrow] == 0.0099) and (direction == 0) :
                            el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,element)

                        elif (dopant[numrow] ==39 ) and (dopant_ratio[numrow] == 0.0099) and (direction == 0) :
                            el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,element)

                        elif (dopant[numrow] ==33 ) and (dopant_ratio[numrow] == 0.0396) and (direction == 0) :
                            el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                        thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,element)


                        numrow+=1
                    
                    ids+=1

    plt.show()
    fig.savefig('./outputdata_search/vacancy/vacancy_'+str(element)+'.pdf',format='pdf')
    
    
    
    
    print('write complete Na')
# Out:
# write complete Na

# %%
numrow=0
starttemp  = 300
endtemp    = 820
steptemp   = 20

zero=0
startratio = 1
endratio   = 5
stepratio  = 1

ids=0
calnum=['Li','Be', 'B','C','Na','Mg', 'Al','Si','P','K','Ca','Sc','Ti','V','Cr','Mn','Fe',\
        'Co','Ni','Cu','Zn','Ga','Ge','As','Rb','Sr','Y','Zr','Nb','Mo','Ru','Rh','Pd','Ag',\
        'Cd','In','Sb','Cs','Ba','Hf','Ta','W','Re','Os','Ir','Pt','Au','Hg','Tl','Pb','Bi']


print(len(calnum))

zt_data=pd.read_csv('./outputdata_search/zt_search_Na.csv',index_col=0)
zt_data_2=pd.read_csv('./outputdata_search/zt_search_Na_se_site.csv',index_col=0)
zt_data=pd.merge(zt_data,zt_data_2, how='outer')
#display(zt_data)

id=zt_data.ID
el_cond=zt_data.el_cond
seebeck=zt_data.seebeck
thermal=zt_data.thermal
zt_pred=zt_data.ZT
temp=zt_data.Temp
sn=zt_data.Sn_ratio
dopant=zt_data.dopant2_num
dopant_ratio=zt_data.dopant2_ratio
direction=zt_data.direction
draw_list=['zt_pick']

pickup_data=pd.read_csv('./outputdata_search/max_zt_list_Na.csv',index_col=0)

for tt in draw_list:
    
    numrow=0
    el_pick=list()
    seebeck_pick=list()
    thermal_pick=list()
    zt_pick=list()
    pf_pick=list()

    fig = plt.figure(figsize=(20,3.5))
    ax0 = plt.subplot(1,5,1)
    ax1 = plt.subplot(1,5,2)
    ax2 = plt.subplot(1,5,3)
    ax3 = plt.subplot(1,5,4)
    ax4 = plt.subplot(1,5,5)
    

    ax0.set_xlim((300,820))
    ax1.set_xlim((300,820))
    ax2.set_xlim((300,820))
    ax3.set_xlim((300,820))
    ax4.set_xlim((300,820))
    


    ax0.set_ylim((0,2.5))
    ax1.set_ylim((0,140))
    ax2.set_ylim((140,450))
    ax3.set_ylim((0.2,0.9))
    ax4.set_ylim((0,11))


    
    ax0.set_xlabel('Temperature')
    ax1.set_xlabel('Temperature')
    ax2.set_xlabel('Temperature')
    ax3.set_xlabel('Temperature')
    ax4.set_xlabel('Temperature')


    ax0.set_ylabel('predicted ZT')
    ax1.set_ylabel('predicted s')
    ax2.set_ylabel('predicted S')
    ax3.set_ylabel('predicted k')
    ax4.set_ylabel('predicted PF')

    mark=['o','v','^','<','>','.','1','2','3','4']
    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    
    q=0


    for j in range(pickup_data.shape[0]):
        endratio=5
        element=pickup_data["dopant"][j]
        endratio_s=solubility[solubility_atomlist.index(element)]
        endratio_s=round(endratio_s)
            
        if endratio > endratio_s:
            endratio = endratio_s
        if endratio_s > 0.5 and endratio_s < 1.0:
            endratio = 1            

            
        for ii in my_range(startratio,endratio,stepratio):  #from 1% to 3%, stepsize=1%
                
            if ii ==5 :
                vacancy = 0
            elif ii==4 : 
                vacancy = 1
            else:
                vacancy = 2


            for jj in my_range(0,vacancy,stepratio):  #from 1% to 3%, stepsize=1%

                x_trial=[] 
                y_fitted=[]

                for direction in [0,1]:

                    for i in my_range(starttemp,endtemp,steptemp): #input of temperature data
                        

                        # Sn substitute
                        atom=pickup_data["dopant_num"][j]
                        ratio=pickup_data["dopant_ratio"][j]
                        atom_name=pickup_data["dopant"][j]

                        if j < 22:
                        
                            if (dopant[numrow] == atom ) and (dopant_ratio[numrow] == ratio) and (direction == 0) :
                                el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_2(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,atom_name)
                        
                        else:

                            if (dopant[numrow] ==atom ) and (dopant_ratio[numrow] == ratio) and (direction == 0) :
                                    el_pick,seebeck_pick,thermal_pick,zt_pick,pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4=pickup_draw_3(el_cond,seebeck,thermal,temp,id,sn,dopant_ratio, numrow, el_pick, seebeck_pick, \
                                    thermal_pick, zt_pick, pf_pick,q,fig,ax0,ax1,ax2,ax3,ax4,atom_name)                            
                            
                        numrow+=1

                    ids+=1

    plt.show()
   
    
    
    
    
    print('write complete Na')
# Out:
# 51
# C:\Users\Yealee\AppData\Roaming\Python\Python38\site-packages\pandas\core\reshape\merge.py:1214: UserWarning: You are merging on int and float columns where the float values are not equal to their int representation
#   warnings.warn(
# write complete Na

# %%
import pandas as pd

# %%
filename='solubility_total.csv'
solubility_df=pd.read_csv(filename,index_col=0)
solubility_atomlist=solubility_df['atom'].values.tolist()
solubility=solubility_df.solubility.values
print(solubility)
# Out:
# [1.59790e+01 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#  5.78000e-01 6.48470e+01 1.93900e+00 8.00000e-02 3.00000e-03 3.67100e+00
#  1.50004e+02 9.76600e+00 7.67800e+00 6.12900e+00 1.90000e-01 2.50000e-02
#  4.02000e-01 8.00000e-02 6.46000e+00 2.70000e-02 7.00000e-03 2.74000e-01
#  1.00000e-02 7.20000e-02 1.55000e-01 3.17150e+01 4.62700e+00 1.63030e+01
#  1.66400e+00 2.05600e+01 1.20500e+00 2.20000e-02 0.00000e+00 0.00000e+00
#  0.00000e+00 0.00000e+00 1.05000e-01 5.59200e+00 2.84900e+00 3.57100e+00
#  2.30270e+01 2.50250e+01 1.13200e+00 0.00000e+00 1.60000e-02 1.65120e+01
#  6.00000e-03 1.00000e-03 0.00000e+00 0.00000e+00 0.00000e+00 4.00000e-03
#  1.21900e+00 1.78500e+00 5.06220e+01 1.24622e+02 1.46970e+01]

# %%
#ZT screening
import pickle
from joblib import dump, load
import csv
import numpy as np
from elements import ELEMENTS
from myfunction import my_range
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

numrow=0
starttemp  = 300
endtemp    = 820
steptemp   = 20

zero=0
startratio = 1
endratio   = 5
stepratio  = 1

ids=0
dopingset=['Na']
element_list_Sn=['Li','Be', 'B','C','Na','Mg', 'Al','Si','P','K','Ca','Sc','Ti','V','Cr','Mn','Fe',\
        'Co','Ni','Cu','Zn','Ga','Ge','As','Rb','Sr','Y','Zr','Nb','Mo','Ru','Rh','Pd','Ag',\
        'Cd','In','Sb','Cs','Ba','Hf','Ta','W','Re','Os','Ir','Pt','Au','Hg','Tl','Pb','Bi']
element_list_Se=['N','O','F','S','Cl','Br','Te','I']


for ordering in dopingset:
    
    csvfile1='./outputdata_search/zt_search_'+str(ordering)+'.csv'
    numrow=0
    if ordering == 'Na':
        element_list=element_list_Sn

        

    elif ordering == 'Na_se_site':
        element_list=element_list_Se



    zt_data=pd.read_csv(csvfile1,index_col=0)

    id=zt_data.ID
    el_cond=zt_data.el_cond
    seebeck=zt_data.seebeck
    thermal=zt_data.thermal
    zt_pred=zt_data.ZT
    temp=zt_data.Temp
    sn=zt_data.Sn_ratio
    dopant=zt_data.dopant2_num
    dopant_ratio=zt_data.dopant2_ratio
    direction=zt_data.direction
    draw_list=['zt_pick']
    total=list()

    for tt in draw_list:

        numrow=0
        zt_pick=list()
        zt_pick1=list()
        vacancylist1=list()
        idlist1=list()
        info1=list()

        zt_pick2=list()
        vacancylist2=list()
        idlist2=list()
        info2=list()    
        zt_pick3=list()
        vacancylist3=list()
        idlist3=list()
        info3=list()    
        zt_pick4=list()
        vacancylist4=list()
        idlist4=list()
        info4=list()     
        zt_pick5=list()
        vacancylist5=list()
        idlist5=list()
        info5=list()    


        temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]

        q=0
        for element in element_list:
            endratio=5
            endratio_s=solubility[solubility_atomlist.index(element)]
            endratio_s=round(endratio_s)


            if endratio > endratio_s:
                endratio = endratio_s
            if endratio_s > 0.5 and endratio_s < 1.0:
                endratio = 1   

            if endratio > 0:

                for ii in my_range(startratio,endratio,stepratio):  #from 1% to 3%, stepsize=1%

                    if ii ==5 :
                        vacancy = 0
                    elif ii==4 : 
                        vacancy = 1
                    else:
                        vacancy = 2


                    for jj in my_range(0,vacancy,stepratio):  #from 1% to 3%, stepsize=1%

                        x_trial=[] 
                        y_fitted=[]

                        for direction in [0,1]:

                            for i in my_range(starttemp,endtemp,steptemp): #input of temperature data

                                if ordering == 'Na' :
                                    composition= [numrow,'TY'+str("{0:0=4d}".format(ids)),(1-(ii+jj)*0.01)*0.99,1,11,0.01,\
                                                  ELEMENTS[element].number,ii*0.01*0.99,0,0,direction,i]
                                elif ordering == 'Na_se_site' :
                                    composition= [numrow,'TY'+str("{0:0=4d}".format(ids)),(1-jj*0.01-0.01),(1-ii*0.01),11,0.01,\
                                              ELEMENTS[element].number,ii*0.01,0,0,direction,i]

                                if (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.0099) < 0.0001) and (direction == 0) :

                                    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                    if id[numrow] != id[numrow+1]:
                                        #print(dopant_ratio[numrow])
                                        #vacancy=(1-(sn[numrow]+dopant_ratio[numrow])/0.99)
                                        idlist1.append('TY'+str("{0:0=4d}".format(ids)))
                                        vacancylist1.append(vacancy)
                                        zt_pick1.append(max(zt_pick))
                                        info1=[ELEMENTS[element].number, 0.0099]
                                        zt_pick=list()

                                elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.0198) < 0.0001) and (direction == 0) :

                                    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                    if id[numrow] != id[numrow+1]:
                                        #print(dopant_ratio[numrow])
                                        #vacancy=(1-(sn[numrow]+dopant_ratio[numrow])/0.99)
                                        idlist2.append('TY'+str("{0:0=4d}".format(ids)))
                                        vacancylist2.append(vacancy)
                                        zt_pick2.append(max(zt_pick))
                                        info2=[ELEMENTS[element].number, 0.0198]

                                        zt_pick=list()

                                elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.0297) < 0.0001) and (direction == 0) :

                                    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                    if id[numrow] != id[numrow+1]:
                                        #print(dopant_ratio[numrow])
                                        #vacancy=(1-(sn[numrow]+dopant_ratio[numrow])/0.99)
                                        idlist3.append('TY'+str("{0:0=4d}".format(ids)))
                                        vacancylist3.append(vacancy)
                                        zt_pick3.append(max(zt_pick))
                                        info3=[ELEMENTS[element].number, 0.0297]

                                        zt_pick=list()                     


                                elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.0396) < 0.0001) and (direction == 0) :

                                    zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                    if id[numrow] != id[numrow+1]:
                                        #print(dopant_ratio[numrow])
                                        #vacancy=(1-(sn[numrow]+dopant_ratio[numrow])/0.99)
                                        idlist4.append('TY'+str("{0:0=4d}".format(ids)))
                                        vacancylist4.append(vacancy)
                                        zt_pick4.append(max(zt_pick))
                                        info4=[ELEMENTS[element].number, 0.0396]

                                        zt_pick=list()    


                                numrow+=1
                            
                            ids+=1
                
                if endratio >3:
                    total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                    total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])
                    total.append([idlist3[zt_pick3.index(max(zt_pick3))],info3[0],info3[1],vacancylist3[zt_pick3.index(max(zt_pick3))],max(zt_pick3), max(zt_pick3)-zt_pick3[0]])
                    total.append([idlist4[zt_pick4.index(max(zt_pick4))],info4[0],info4[1],vacancylist4[zt_pick4.index(max(zt_pick4))],max(zt_pick4), max(zt_pick4)-zt_pick4[0]])

                elif endratio ==3:

                    total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                    total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])      
                    total.append([idlist3[zt_pick3.index(max(zt_pick3))],info3[0],info3[1],vacancylist3[zt_pick3.index(max(zt_pick3))],max(zt_pick3), max(zt_pick3)-zt_pick3[0]])
                elif endratio == 2:
                    total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                    total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])      

                elif endratio == 1:
                    total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])

                zt_pick1=list()
                vacancylist1=list()
                idlist1=list()
                info1=list()
                zt_pick2=list()
                vacancylist2=list()
                idlist2=list()
                info2=list()
                zt_pick3=list()
                vacancylist3=list()
                idlist3=list()
                info3=list()    
                zt_pick4=list()
                vacancylist4=list()
                idlist4=list()
                info4=list()    
    print('write complete Na')

    data=pd.DataFrame(total)

    data.columns=['ID','alloying_atom','rate','vacancy','maxZT','improvement']
    data.to_csv('./outputdata_search/vacancy_improvement.csv')
    display(data)
# Out:
# write complete Na
#         ID  alloying_atom    rate  vacancy     maxZT  improvement
# 0   TY0004              3  0.0099        2  1.439051     0.217734
# 1   TY0010              3  0.0198        2  1.578543     0.307422
# 2   TY0014              3  0.0297        2  1.704257     0.313744
# 3   TY0020              3  0.0396        1  1.426902     0.048524
# 4   TY0028             11  0.0099        2  1.534835     0.465946
# ..     ...            ...     ...      ...       ...          ...
# 70  TY0418             82  0.0396        1  1.927222     0.389841
# 71  TY0424             83  0.0099        2  1.280144     0.025416
# 72  TY0430             83  0.0198        2  1.157165     0.172297
# 73  TY0436             83  0.0297        2  1.245255     0.112543
# 74  TY0442             83  0.0396        1  1.376557     0.366916
#
# [75 rows x 6 columns]

# %%
numrow=0
starttemp  = 300
endtemp    = 820
steptemp   = 20

zero=0
startratio = 1
endratio   = 5
stepratio  = 1

ids=0

element_list=['N','O','F','S','Cl','Br','Te','I']
        


zt_data=pd.read_csv('./outputdata_search/zt_search_Na_se_site.csv',index_col=0)
id=zt_data.ID
el_cond=zt_data.el_cond
seebeck=zt_data.seebeck
thermal=zt_data.thermal
zt_pred=zt_data.ZT
temp=zt_data.Temp
sn=zt_data.Sn_ratio
se=zt_data.Se_ratio
dopant=zt_data.dopant2_num
dopant_ratio=zt_data.dopant2_ratio
direction=zt_data.direction
draw_list=['zt_pick']
total=list()
for tt in draw_list:
    
    numrow=0
    zt_pick=list()
    zt_pick1=list()
    vacancylist1=list()
    idlist1=list()
    info1=list()
    
    zt_pick2=list()
    vacancylist2=list()
    idlist2=list()
    info2=list()    
    zt_pick3=list()
    vacancylist3=list()
    idlist3=list()
    info3=list()    
    zt_pick4=list()
    vacancylist4=list()
    idlist4=list()
    info4=list()     
    zt_pick5=list()
    vacancylist5=list()
    idlist5=list()
    info5=list()    


    temp_pick=[300,320,340,360,380,400,420,440,460,480,500,520,540,560,580,600,620,640,660,680,700,720,740,760,780,800,820]
    
    q=0
    for element in element_list:
        endratio=5
        endratio_s=solubility[solubility_atomlist.index(element)]
        endratio_s=round(endratio_s)


        if endratio > endratio_s:
            endratio = endratio_s
        if endratio_s > 0.5 and endratio_s < 1.0:
            endratio = 1   

        if endratio > 0:
            
            for ii in my_range(startratio,endratio,stepratio):  #from 1% to 3%, stepsize=1%

                if ii ==5 :
                    vacancy = 0
                elif ii==4 : 
                    vacancy = 1
                else:
                    vacancy = 2


                for jj in my_range(0,vacancy,stepratio):  #from 1% to 3%, stepsize=1%

                    x_trial=[] 
                    y_fitted=[]

                    for direction in [0,1]:

                        for i in my_range(starttemp,endtemp,steptemp): #input of temperature data

                            composition= [numrow,'TY'+str("{0:0=4d}".format(ids)),(1-jj*0.01-0.01),(1-ii*0.01),11,0.01,\
                                          ELEMENTS[element].number,ii*0.01,0,0,direction,i]


                            

                            if (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.01) < 0.0001) and (direction == 0) :

                                zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                if id[numrow] != id[numrow+1]:
                                    #print(dopant_ratio[numrow])

                                    idlist1.append('TY'+str("{0:0=4d}".format(ids)))
                                    vacancylist1.append(vacancy)
                                    zt_pick1.append(max(zt_pick))
                                    info1=[ELEMENTS[element].number, 0.01]
        
                                    zt_pick=list()

                            elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.02) < 0.0001) and (direction == 0) :

                                zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                if id[numrow] != id[numrow+1]:
                                    #print(dopant_ratio[numrow])


                                    idlist2.append('TY'+str("{0:0=4d}".format(ids)))
                                    vacancylist2.append(vacancy)
                                    zt_pick2.append(max(zt_pick))
                                    info2=[ELEMENTS[element].number, 0.02]

                                    zt_pick=list()

                            elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.03) < 0.0001) and (direction == 0) :

                                zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                if id[numrow] != id[numrow+1]:
                                    #print(dopant_ratio[numrow])


                                    idlist3.append('TY'+str("{0:0=4d}".format(ids)))
                                    vacancylist3.append(vacancy)
                                    zt_pick3.append(max(zt_pick))
                                    info3=[ELEMENTS[element].number, 0.03]

                                    zt_pick=list()                     


                            elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.04) < 0.0001) and (direction == 0) :

                                zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                if id[numrow] != id[numrow+1]:
                                    #print(dopant_ratio[numrow])


                                    idlist4.append('TY'+str("{0:0=4d}".format(ids)))
                                    vacancylist4.append(vacancy)
                                    zt_pick4.append(max(zt_pick))
                                    info4=[ELEMENTS[element].number, 0.04]

                                    zt_pick=list()                                                     

                            elif (dopant[numrow] == ELEMENTS[element].number ) and (np.absolute(dopant_ratio[numrow] - 0.05) < 0.0001) and (direction == 0) :

                                zt_pick.append(el_cond[numrow]*seebeck[numrow]*seebeck[numrow]*temp[numrow]/thermal[numrow]*10**(-10))

                                if id[numrow] != id[numrow+1]:
                                    #print(dopant_ratio[numrow])


                                    idlist5.append('TY'+str("{0:0=4d}".format(ids)))
                                    vacancylist5.append(vacancy)
                                    zt_pick5.append(max(zt_pick))
                                    info5=[ELEMENTS[element].number, 0.05]

                                    zt_pick=list()                     
                            
                            numrow+=1
                        ids+=1

            if endratio ==5:
                total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])
                total.append([idlist3[zt_pick3.index(max(zt_pick3))],info3[0],info3[1],vacancylist3[zt_pick3.index(max(zt_pick3))],max(zt_pick3), max(zt_pick3)-zt_pick3[0]])
                total.append([idlist4[zt_pick4.index(max(zt_pick4))],info4[0],info4[1],vacancylist4[zt_pick4.index(max(zt_pick4))],max(zt_pick4), max(zt_pick4)-zt_pick4[0]])
                total.append([idlist5[zt_pick5.index(max(zt_pick5))],info5[0],info5[1],vacancylist5[zt_pick5.index(max(zt_pick5))],max(zt_pick4), max(zt_pick4)-zt_pick5[0]])
            elif endratio ==4:
                total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])
                total.append([idlist3[zt_pick3.index(max(zt_pick3))],info3[0],info3[1],vacancylist3[zt_pick3.index(max(zt_pick3))],max(zt_pick3), max(zt_pick3)-zt_pick3[0]])
                total.append([idlist4[zt_pick4.index(max(zt_pick4))],info4[0],info4[1],vacancylist4[zt_pick4.index(max(zt_pick4))],max(zt_pick4), max(zt_pick4)-zt_pick4[0]])

            elif endratio ==3:
                total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])      
                total.append([idlist3[zt_pick3.index(max(zt_pick3))],info3[0],info3[1],vacancylist3[zt_pick3.index(max(zt_pick3))],max(zt_pick3), max(zt_pick3)-zt_pick3[0]])
            elif endratio == 2:
                total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                total.append([idlist2[zt_pick2.index(max(zt_pick2))],info2[0],info2[1],vacancylist2[zt_pick2.index(max(zt_pick2))],max(zt_pick2), max(zt_pick2)-zt_pick2[0]])      

            elif endratio == 1:
                total.append([idlist1[zt_pick1.index(max(zt_pick1))],info1[0],info1[1],vacancylist1[zt_pick1.index(max(zt_pick1))],max(zt_pick1), max(zt_pick1)-zt_pick1[0]])
                        
            zt_pick1=list()
            vacancylist1=list()
            idlist1=list()
            info1=list()
            zt_pick2=list()
            vacancylist2=list()
            idlist2=list()
            info2=list()
            zt_pick3=list()
            vacancylist3=list()
            idlist3=list()
            info3=list()    
            zt_pick4=list()
            vacancylist4=list()
            idlist4=list()
            info4=list()    
            zt_pick5=list()
            vacancylist5=list()
            idlist5=list()
            info5=list()    

    print('write complete Na')

    data=pd.DataFrame(total)
    data.columns=['ID','alloying_atom','rate','vacancy','maxZT','improvement']    
    data.to_csv('./outputdata_search/vacancy_improvement2.csv')
# Out:
# write complete Na

# %%
data=pd.read_csv('./outputdata_search/vacancy_improvement.csv',index_col=0)
data2=pd.read_csv('./outputdata_search/vacancy_improvement2.csv',index_col=0)
data=pd.merge(data,data2, how='outer')

x=data.alloying_atom
zt_list=data.maxZT
zt_pick=[]
id_pick=[]
id_list=data.ID


zt_dopant=[]


for i, zt in enumerate(zt_list):
    
    id_pick.append(i)
    zt_pick.append(zt)
   
    if i == len(zt_list)-1 : 
        ttt = id_pick[zt_pick.index(max(zt_pick))]
        zt_dopant.append([id_list[ttt],data["alloying_atom"][ttt],\
           data["rate"][ttt], data["vacancy"][ttt], data["maxZT"][ttt], data["improvement"][ttt]])

        break
        
    elif x[i] != x[i+1]:

        ttt = id_pick[zt_pick.index(max(zt_pick))]

        zt_dopant.append([id_list[ttt],data["alloying_atom"][ttt],\
           data["rate"][ttt], data["vacancy"][ttt], data["maxZT"][ttt], data["improvement"][ttt]])

        
        
        zt_pick=[]      
        id_pick=[]
        
df=pd.DataFrame(zt_dopant)        
df.columns=['ID','alloying_atom','rate','vacancy','maxZT','improvement']   
display(df)
df.to_csv("./outputdata_search/vacancy_improvement_max.csv")
# Out:
#         ID  alloying_atom    rate  vacancy     maxZT  improvement
# 0   TY0014              3  0.0297        2  1.704257     0.313744
# 1   TY0034             11  0.0198        2  1.554323     0.613792
# 2   TY0058             12  0.0198        2  1.651004     0.595453
# 3   TY0070             15  0.0198        2  1.302631     0.038536
# 4   TY0092             19  0.0198        2  1.601574     0.532492
# 5   TY0116             20  0.0198        2  1.712508     0.586800
# 6   TY0134             25  0.0099        2  1.690926     0.313240
# 7   TY0172             32  0.0396        1  2.392701     0.000000
# 8   TY0196             33  0.0396        1  2.005168     0.000000
# 9   TY0206             37  0.0099        2  1.852786     0.397849
# 10  TY0218             38  0.0099        2  1.912038     0.606453
# 11  TY0242             39  0.0099        2  2.080784     0.197514
# 12  TY0244             47  0.0099        2  1.533199     0.000000
# ...

# %%
data=pd.read_csv('./outputdata_search/vacancy_improvement_max.csv',index_col=0)
x=data.alloying_atom
y=data.improvement

fig, ax = plt.subplots(figsize=(12,3.5))
plt.xlim(1,85)
#ax.yaxis.set_major_formatter(formatter)
plt.bar(x, y, width=0.9)
plt.xticks(np.arange(3, 84, step=1), labels=['3','', '','6','','','9','','','12','','','15','','','18','','','21','','','24',\
                                             '','','27','','','30','','','33','','','36','','','39','','','42','','','45','','','48',\
                                            '','','51','','','54','','','57','','','60','','','63','','','66','','','69','','','72',\
                                            '','','75','','','78','','','81','','','84'])


ax.set_xlabel('Atomic number')
ax.set_ylabel('improved ZT')
fig.savefig('./outputdata_search/vacancy_improved.pdf',format='pdf')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-3031fc877f5f> in <module>
#       7 #ax.yaxis.set_major_formatter(formatter)
#       8 plt.bar(x, y, width=0.9)
# ----> 9 plt.xticks(np.arange(3, 84, step=1), labels=['3','', '','6','','','9','','','12','','','15','','','18','','','21','','','24',\
#      10                                              '','','27','','','30','','','33','','','36','','','39','','','42','','','45','','','48',\
#      11                                             '','','51','','','54','','','57','','','60','','','63','','','66','','','69','','','72',\
#
# ~\AppData\Roaming\Python\Python38\site-packages\matplotlib\pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
# ...

# %%
fig = plt.figure(figsize=(40,20))
fig, ax = plt.subplots()
plt.scatter(x, y, c=y)
plt.colorbar(label='dopant number')
plt.show()

fig.savefig('./outputdata_search/vacancy_scatter.pdf', format='pdf')

# %%
from periodic_table_heatmap import periodic_table_heatmap 
from bokeh.sampledata.periodic_table import elements

filename='./outputdata_search/vacancy_improvement_max.csv'
df=pd.read_csv(filename,index_col=0)
data_elements=df.alloying_atom
data=df.improvement
blank_color='white'
under_value=0
over_value=100

color_list = [blank_color] * len(elements)
quantity_list=[0]*len(elements)

for i, atomnum in enumerate(data_elements):
    
    data_element=ELEMENTS[atomnum].symbol
    element_entry = elements.symbol[
        elements.symbol.str.lower() == data_element.lower()
        ]
        
    if element_entry.empty == False:
        element_index = element_entry.index[0]
    else:
        warnings.warn("Invalid chemical symbol: " + data_element)
            
            
            
    if color_list[element_index] != blank_color:
        warnings.warn("Multiple entries for element " + data_element)
    elif under_value is not None and data[i] <= under_value:
        
        quantity_list[element_index] = round(data[i],2)
    elif over_value is not None and data[i] >= over_value:
        
        quantity_list[element_index] = round(data[i],2)
    else:
        
        quantity_list[element_index] = round(data[i],2)


quantity_list[31]=0.01  #for drawing
quantity_list[32]=0.01
quantity_list[46]=0.01

string_list = elements["symbol"]


dictionary = dict(zip(string_list, quantity_list))
print(dictionary)


fig=periodic_table_heatmap(dictionary, cbar_label='', \
                                                     cbar_label_size=14, show_plot=False, cmap='YlOrRd', \
                                                     cmap_range=(0.01,1), blank_color='white', edge_color='black', \
                                                     value_format="%.2f", value_fontsize=12, symbol_fontsize=14, \
                                                     max_row=6, readable_fontcolor=True)

fig.savefig('max_zt_list_Na.pdf')
# Out:
# {'H': 0, 'He': 0, 'Li': 0.31, 'Be': 0, 'B': 0, 'C': 0, 'N': 0, 'O': 0, 'F': 0.33, 'Ne': 0, 'Na': 0.61, 'Mg': 0.6, 'Al': 0, 'Si': 0, 'P': 0.04, 'S': 0.32, 'Cl': 0.46, 'Ar': 0, 'K': 0.53, 'Ca': 0.59, 'Sc': 0, 'Ti': 0, 'V': 0, 'Cr': 0, 'Mn': 0.31, 'Fe': 0, 'Co': 0, 'Ni': 0, 'Cu': 0, 'Zn': 0, 'Ga': 0, 'Ge': 0.01, 'As': 0.01, 'Se': 0, 'Br': 0.2, 'Kr': 0, 'Rb': 0.4, 'Sr': 0.61, 'Y': 0.2, 'Zr': 0, 'Nb': 0, 'Mo': 0, 'Tc': 0, 'Ru': 0, 'Rh': 0, 'Pd': 0, 'Ag': 0.01, 'Cd': 0.59, 'In': 0.0, 'Sn': 0, 'Sb': 0.3, 'Te': 0.33, 'I': 0.56, 'Xe': 0, 'Cs': 0, 'Ba': 0.54, 'La': 0, 'Ce': 0, 'Pr': 0, 'Nd': 0, 'Pm': 0, 'Sm': 0, 'Eu': 0, 'Gd': 0, 'Tb': 0, 'Dy': 0, 'Ho': 0, 'Er': 0, 'Tm': 0, 'Yb': 0, 'Lu': 0, 'Hf': 0, 'Ta': 0, 'W': 0, 'Re': 0, 'Os': 0, 'Ir': 0, 'Pt': 0, 'Au': 0.43, 'Hg': 0.25, 'Tl': 0.69, 'Pb': 0.95, 'Bi': 0.37, 'Po': 0, 'At': 0, 'Rn': 0, 'Fr': 0, 'Ra': 0, 'Ac': 0, 'Th': 0, 'Pa': 0, 'U': 0, 'Np': 0, 'Pu': 0, 'Am': 0, 'Cm': 0, 'Bk': 0, 'Cf': 0, 'Es': 0, 'Fm': 0, 'Md': 0, 'No': 0, 'Lr': 0, 'Rf': 
# ...
